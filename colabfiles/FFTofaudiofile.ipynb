# %% [markdown]
# <a href="https://colab.research.google.com/github/Jash7447/my-colaboratories/blob/main/FFTofaudiofile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy scipy matplotlib

# %%
import scipy.io.wavfile as wav
import numpy as np

# Load the audio file
sample_rate, audio_data = wav.read("file_example_WAV_1MG.wav")
print(sample_rate, audio_data)
# Out:
# 44100 [[ 0  0]
#  [ 0  0]
#  [ 0  0]
#  ...
#  [-2 -2]
#  [ 0  2]
#  [ 2 -2]]
# <ipython-input-10-16de7cd4c379>:5: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, audio_data = wav.read("file_example_WAV_1MG.wav")

# %%
import numpy as np

# Perform the FFT
fft_result = np.fft.fft(audio_data)

# Calculate the corresponding frequencies
frequencies = np.fft.fftfreq(len(fft_result), 1 / sample_rate)

# %%
import matplotlib.pyplot as plt

# Plot the FFT result
plt.figure(figsize=(10, 6))
plt.plot(frequencies, np.abs(fft_result))
plt.title("FFT of Audio Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.grid()
plt.show()

# %%
fft_result = np.fft.fft(audio_data)
frequencies = np.fft.fftfreq(len(fft_result), 1 / sample_rate)

# Create a time array for the audio waveform
time = np.arange(0, len(audio_data)) / sample_rate

# Plot the audio waveform
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, audio_data)
plt.title("Audio Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid()

# Plot the FFT result
plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(fft_result))
plt.title("FFT of Audio Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.grid()

plt.tight_layout()
plt.show()
